# %% [markdown]
# # overview of the dataset:
#                         From the given dataset its clear that data belongs to health care industry and dataset focus on
#
#          hepatitis patients
#
# #This rises the question what is hepatitis?
#
#                                             hepatitis refers to an inflammatory condition of the liver. Its commonly caused by
#
#              viral infection,  but there are other possible causes of hepatitis. These include autoimmune hepatitis and
#
#             hepatitis that occurs as a secondary result of medications, drugs, toxins, and alcohol.

# %% [markdown]
# # Field names and observation:
#                              After an overview the next phase is to know the field names and No of observation in the dataset
#
#     the dataset contains 156 rows and 20 variables. The following are the variables in the dataset they are
#
#
# #Age-> This variable describe the age of the patients with hepatitis.
#
# #Sex-> Describe the gender of patients.
#
# #Steroid-> To know whether the patients were prescribed for steriod use.
#
# #Antivirals-> An agent that kills a virus or that suppresses its ability to replicate and, hence, inhibits its capability to multiply and reproduce.
#
# #Fatigue-> Feeling overtired, with low energy and a strong desire to sleep that interferes with normal daily activities.
#
# #Malaise-> A general feeling of discomfort, illness, or unease whose exact cause is difficult to identify.
#
# #Anorexia-> Is an eating disorder characterized by an abnormally low body weight, an intense fear of gaining weight and a distorted perception of weight.
#
# #Liver_big-> Liver_big means enlarged liver,An enlarged liver can have causes that aren't due to underlying disease.
#
# #Liver_firm-> Its means whether liver is noraml or does it show an abnormality.
#
# #Spleen_palpable-> The normal adult spleen lies immediately under the diaphragm in the left upper quadrant of the abdomen. It ranges in length from 6 to 13 cm and in weight from 75 to 120 g. The spleen is not normally palpable except in slender young adults.
#
# #Spiders-> Spider nevi are benign vascular lesions mostly seen in patients with decompensated liver cirrhosis.
#
# #Ascites-> Ascites is the abnormal buildup of fluid in the abdomen.
#
# #Varices->  Is an abnormally dilated vessel with a tortuous course. Varices usually occur in the venous system, but may also occur in arterial or lymphatic vessels.
#
# #Bilirubin-> Bilirubin is a yellowish substance in your blood. It forms after red blood cells break down, and it travels through your liver
#
# #Alk_phosphate-> Alkaline phosphatase, or basic phosphatase, is a homodimeric protein enzyme of 86 kilodaltons. Each monomer contains five cysteine residues, two zinc atoms and one magnesium atom crucial to its catalytic function, and it is optimally active at alkaline pH environments.
#
# #Sgot-> The SGOT test is a blood test that's part of a liver profile.
#
# #Albumin-> Albumin is a protein made by your liver. Albumin helps keep fluid in your bloodstream so it doesn't leak into other tissues.
#
# #Protime-> Prothrombin time (PT) is a blood test that measures how long it takes blood to clot.
#
# #Histology-> Histology is a routine lab technique used to evaluate the morphology and structure of cells, tissues, and organs under the microscope.
#
# #Class-> This varirable show the patients is alive or died.

# %% [markdown]
# # After a total understanding of the dataset we can clearly know that variable "class" is dependent varaible and rest of the
#
# variable is independent variable (so next phase is to move to machine learning process for this dataset we can use Random
#
# ForestDecesion tree and Logistic regression), Since machine learning process is not requried we can move on with
#
# exploratory data analysis(E.D.A):
#
# Exploratory Data Analysis refers to the critical process of performing initial investigations on data so as to discover
#
# patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and
#
# graphical representations.

# %% [markdown]
# # Necessary dictionaries for analysis & importing dictionaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # Read dataset

# %%
data=pd.read_csv('hepatitis_csv.csv')

# %%
data
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %% [markdown]
# Now the dataset named "hepatitis_csv.csv" is read with variable name as data,we should note that when we view this dataset in
#
# excel its show 156 rows and when we import the data no of rows is 155, this is because pyhton reads starting with 0 and not
#
# with 1.

# %% [markdown]
# # Head ()

# %%
data.head()
# Out:
#    age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0   30    male   False       False   False   False    False     False
# 1   50  female   False       False    True   False    False     False
# 2   78  female    True       False    True   False    False      True
# 3   31  female     NaN        True   False   False    False      True
# 4   34  female    True       False   False   False    False      True
#
#   liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 0      False           False   False   False   False        1.0
# 1      False           False   False   False   False        0.9
# 2      False           False   False   False   False        0.7
# 3      False           False   False   False   False        0.7
# 4      False           False   False   False   False        1.0
#
#    alk_phosphate   sgot  albumin  protime  histology class
# 0           85.0   18.0      4.0      NaN      False  live
# ...

# %% [markdown]
# Show frist 5 rows in the dataset

# %% [markdown]
# # Tail()

# %%
data.tail()
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 150      False           False    True    True    True        7.6
# 151       True           False   False   False   False        0.9
# 152       True           False    True   False   False        0.8
# 153      False            True    True   False    True        1.5
# 154      False            True    True    True   False        1.2
#
#      alk_phosphate   sgot  albumin  protime  histology class
# 150            NaN  242.0      3.3     50.0       True   die
# ...

# %% [markdown]
# Show last five records in the dataset

# %% [markdown]
# # Shape of the dataset

# %%
data.shape
# Out:
# (155, 20)

# %% [markdown]
# 155 rows and 20 columns

# %% [markdown]
# # Info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              155 non-null    int64
#  1   sex              155 non-null    int64
#  2   steroid          155 non-null    int64
#  3   antivirals       155 non-null    int64
#  4   fatigue          155 non-null    int64
#  5   malaise          155 non-null    int64
#  6   anorexia         155 non-null    int64
#  7   liver_big        155 non-null    int64
#  8   liver_firm       155 non-null    int64
#  9   spleen_palpable  155 non-null    int64
#  10  spiders          155 non-null    int64
#  11  ascites          155 non-null    int64
#  12  varices          155 non-null    int64
#  13  bilirubin        149 non-null    float64
#  14  alk_phosphate    126 non-null    float64
#  15  sgot             151 non-null    float64
#  16  albumin          139 non-null    float64
# ...

# %% [markdown]
# info() shows the datatype for each variable

# %% [markdown]
# # Describe

# %%
data.describe()
# Out:
#               age         sex     steroid  antivirals     fatigue     malaise  \
# count  155.000000  155.000000  155.000000  155.000000  155.000000  155.000000
# mean    41.200000    0.103226    0.516129    0.154839    0.658065    0.406452
# std     12.565878    0.305240    0.514148    0.362923    0.489350    0.505769
# min      7.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     32.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%     39.000000    0.000000    1.000000    0.000000    1.000000    0.000000
# 75%     50.000000    0.000000    1.000000    0.000000    1.000000    1.000000
# max     78.000000    1.000000    2.000000    1.000000    2.000000    2.000000
#
#          anorexia   liver_big  liver_firm  spleen_palpable     spiders  \
# count  155.000000  155.000000  155.000000       155.000000  155.000000
# mean     0.219355    0.903226    0.529032         0.258065    0.393548
# ...

# %% [markdown]
# describe() function is useful to know about statistics summary

# %% [markdown]
# # Unique

# %%
data.steroid.unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %% [markdown]
# Unique function is used to know how any elements does a variable contains here the elements are 0,1 and 2

# %% [markdown]
# # Value counts

# %%
data.albumin.value_counts()
# Out:
# 4.0    25
# 4.2    13
# 4.4     9
# 3.8     9
# 4.1     8
# 3.9     8
# 4.3     7
# 3.5     6
# 3.3     6
# 2.9     5
# 3.0     5
# 4.5     4
# 3.4     4
# 3.7     3
# 2.8     3
# 2.6     3
# 2.7     3
# 3.1     3
# 4.9     2
# 4.6     2
# 2.4     2
# 3.6     2
# 5.0     1
# 4.8     1
# 2.2     1
# 6.4     1
# 4.7     1
# 5.3     1
# 2.1     1
# Name: albumin, dtype: int64

# %% [markdown]
# value count show how anytimes an elements is present in a dataset,here 4.0 as 25 counts

# %% [markdown]
# # Since most of the data is in logical opeartor we use Label_Encoder

# %%
from sklearn.preprocessing import LabelEncoder
L_B=LabelEncoder()

# %%
data['sex'] = L_B.fit_transform(data['sex'])
data['steroid'] = L_B.fit_transform(data['steroid'])
data['antivirals'] = L_B.fit_transform(data['antivirals'])
data['fatigue'] = L_B.fit_transform(data['fatigue'])
data['malaise'] = L_B.fit_transform(data['malaise'])
data['anorexia'] = L_B.fit_transform(data['anorexia'])
data['liver_big'] = L_B.fit_transform(data['liver_big'])
data['liver_firm'] = L_B.fit_transform(data['liver_firm'])
data['spleen_palpable'] = L_B.fit_transform(data['spleen_palpable'])
data['spiders'] = L_B.fit_transform(data['spiders'])
data['ascites'] = L_B.fit_transform(data['ascites'])
data['varices'] = L_B.fit_transform(data['varices'])
data['histology'] = L_B.fit_transform(data['histology'])
data['class'] = L_B.fit_transform(data['class'])

# %%
data
# Out:
#      age  sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0     30    1        0           0        0        0         0          0
# 1     50    0        0           0        1        0         0          0
# 2     78    0        1           0        1        0         0          1
# 3     31    0        2           1        0        0         0          1
# 4     34    0        1           0        0        0         0          1
# ..   ...  ...      ...         ...      ...      ...       ...        ...
# 150   46    0        1           0        1        1         1          1
# 151   44    0        1           0        1        0         0          1
# 152   61    0        0           0        1        1         0          0
# 153   53    1        0           0        1        0         0          1
# 154   43    0        1           0        1        0         0          1
#
#      liver_firm  spleen_palpable  spiders  ascites  varices  bilirubin  \
# ...

# %% [markdown]
# Now all the records that are in logical opeartor is converted into binary

# %% [markdown]
# # Check null values

# %%
data.isnull().sum()
# Out:
# age                 0
# sex                 0
# steroid             0
# antivirals          0
# fatigue             0
# malaise             0
# anorexia            0
# liver_big           0
# liver_firm          0
# spleen_palpable     0
# spiders             0
# ascites             0
# varices             0
# bilirubin           6
# alk_phosphate      29
# sgot                4
# albumin            16
# protime            67
# histology           0
# class               0
# dtype: int64

# %% [markdown]
# By using isnull() we found the variable that have null values,when a single variable or multiple variable null values is higher we tend to drop the variable

# %% [markdown]
# # Dropping null values

# %%
anl=data.dropna()

# %%
anl
# Out:
#      age  sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 3     31    0        2           1        0        0         0          1
# 5     34    0        1           0        0        0         0          1
# 10    39    0        0           1        0        0         0          0
# 11    32    0        1           1        1        0         0          1
# 12    41    0        1           1        1        0         0          1
# ..   ...  ...      ...         ...      ...      ...       ...        ...
# 143   49    0        0           0        1        1         0          1
# 145   31    0        0           0        1        0         0          1
# 147   70    0        0           0        1        1         1          2
# 153   53    1        0           0        1        0         0          1
# 154   43    0        1           0        1        0         0          1
#
#      liver_firm  spleen_palpable  spiders  ascites  varices  bilirubin  \
# ...

# %%
anl.isnull().sum()
# Out:
# age                0
# sex                0
# steroid            0
# antivirals         0
# fatigue            0
# malaise            0
# anorexia           0
# liver_big          0
# liver_firm         0
# spleen_palpable    0
# spiders            0
# ascites            0
# varices            0
# bilirubin          0
# alk_phosphate      0
# sgot               0
# albumin            0
# protime            0
# histology          0
# class              0
# dtype: int64

# %% [markdown]
# we have dropped all the null values in the dataset

# %% [markdown]
# # Correlation analysis

# %%
al_cor=anl.corr()

# %%
al_cor
# Out:
#                       age       sex   steroid  antivirals   fatigue   malaise  \
# age              1.000000 -0.057162 -0.058915   -0.003118  0.149746  0.131593
# sex             -0.057162  1.000000  0.011467    0.087298  0.062855 -0.027118
# steroid         -0.058915  0.011467  1.000000    0.017619 -0.126985 -0.211669
# antivirals      -0.003118  0.087298  0.017619    1.000000 -0.075189 -0.041665
# fatigue          0.149746  0.062855 -0.126985   -0.075189  1.000000  0.595352
# malaise          0.131593 -0.027118 -0.211669   -0.041665  0.595352  1.000000
# anorexia        -0.153682  0.027092 -0.056546   -0.033481  0.315809  0.530458
# liver_big        0.091692 -0.047694  0.104508   -0.140860  0.009799  0.083710
# liver_firm       0.272872  0.093301 -0.180050   -0.006625  0.262618  0.148836
# spleen_palpable  0.263929 -0.031109 -0.080723   -0.233757  0.188740  0.103050
# spiders          0.257508  0.102358 -0.014631   -0.229904  0.329420  0.312511
# ...

# %% [markdown]
# With the help of heatmap we can visulize correlation

# %%
plt.subplots(figsize=(20,15))
sb.heatmap(al_cor,annot=True,cmap="YlGnBu",linewidths=.5)

# %% [markdown]
# Darker shade represents positive correlation and lighter shades represents negative correlation,annot feature helps to know by
#
# which features are correlated to each other

# %% [markdown]
# # Visualization

# %% [markdown]
# # Boxplot

# %%
plt.subplots(figsize=(20,15))
sb.barplot(x="liver_firm", y="age", hue="sex", data=anl,color="teal", saturation=.8)

# %% [markdown]
# Barplot are helpful when a data is univariate here Male-1 and Female-0
#
# Here female Liver_firm is higher than male patients and does not show any abnormality

# %% [markdown]
# # Scatterplot

# %%
sb.scatterplot(anl['steroid'],anl['anorexia'])

# %% [markdown]
# # Distplot

# %%
sb.distplot(anl.steroid,rug=True,hist=True,color='firebrick')

# %% [markdown]
# distplot helps us to know that are high no of steriod users are 1 and least is no of steriod users is 2

# %% [markdown]
# # Boxplot

# %%
plt.subplots(figsize=(7,10))
sb.boxplot(x='fatigue',y='age',data=anl,linewidth=2.5,color='skyblue')

# %% [markdown]
# boxplot is commonly used for outlinear identification, patients who fall under catgeory 1 have muscle fatigue between the age
#
# 34 and 52 due to medication of steriod (or) common factor for hepatitis patients.

# %% [markdown]
# # Violinplot

# %%
sb.violinplot(x=anl['class'],y=anl['liver_big'],color='crimson')

# %% [markdown]
# Vilionplot is combination of boxplot and kernal density plot in this vilionplot we know that the hepatitis patients
#
# who are all alive that is class 1 have no significant liver_big or liver enlargement on the other hand people who die
#
# had a significant liver enlargement.

# %% [markdown]
# # Swarmplot

# %%
sb.swarmplot(x=anl["sex"],y=anl['albumin'])

# %% [markdown]
# Swarmplot is similar to striplot,it shows that female had albumin secretion than higher male

# %% [markdown]
# # Pairplot

# %%
sb.pairplot(anl)

# %% [markdown]
# pairplot is used to plot multiple pairwise bivariate distributions in a dataset

# %% [markdown]
# # Jointplot

# %%
sb.jointplot(data=anl, x="sgot", y="histology",kind='kde',color='yellow')

# %% [markdown]
# jointplot displays a relationship between 2 variables (bivariate) as well as 1D profiles (univariate)
#
# from this joint plot its clear that most of hepatitis patients have not taken histology test that is 85% of patients
#
# on the other hand most of the people had taken sgot test

# %% [markdown]
# # Scatterplot

# %%
plt.scatter(x=anl['protime'],y=anl['sgot'],marker='*',color='green',edgecolor='red',linewidth=1.5)
plt.xlabel('protime')
plt.ylabel('sgot')
# Out:
# Text(0, 0.5, 'sgot')

# %% [markdown]
# Scatter plots primary uses are to observe and show relationships between two numeric variables. From this scatter plot its
#
# clear that Protime and sgot is not postive correlated and patients taken either of the test not Compulsory both the test.

# %% [markdown]
# # Conclusion

# %% [markdown]
# From this analysis we are clear that out 155 paitents 123 paitents are alive and healthy and most of the paitents
#
# refer sgot test other than any other test. patients have taken steriod for medication purpose, Female liver_firm is normal than
#
# male patients and there is no Liver enlargement in hepatitis patients who are alive. Female paitents secreated more albunim
#
# then male patients.
